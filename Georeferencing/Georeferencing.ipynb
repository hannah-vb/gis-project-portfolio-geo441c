# %% [markdown]
# <a href="https://colab.research.google.com/github/hannah-vb/gis-project-portfolio-geo441c/blob/main/Georeferencing/Georeferencing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441/541C Week 4 In-Class Activity: Georeferencing**

# %% [markdown]
# 🚀 Created by Hannah VanBuren
#
# 02/20/2026

# %% [markdown]
# ### **0. Get ready to start**
#
# - Use **`File\Save a copy in Drive`** to make a copy of this notebook in my own Google Drive
# - By default, this notebooks will be saved to a new folder called **`Colab`** under root directory of my Google Drive
#
# ---

# %% [markdown]
# ### **1. Overview**
#
# - In this assignment, we will use georeference to assign a historical map of our campus in the 1960s with correct map coordinates so that it can be ovelaid on a basemap showing the current landscape of our campus
# - By comparing the historical map and the basemap, we will be able to identify the changes happened on and near our campus during the the past several decades
#
# ![MU map](https://spec.lib.miamioh.edu/revisitingoxford/files/original/954b7bea7110f58726dbfd1137f5aec8.jpg)
#
#
# *A historical map of Miami University Oxford campus back in 1960s*
#
# ---

# %% [markdown]
# ### **2. Learn about Steps in Georeferencing**
#
# - Watch [this video](https://youtu.be/J-to3kHo1Ug?feature=shared) to learn how to georeference a map in ArcGIS Pro
# - Esri official help document for [Georeferencing tool](https://pro.arcgis.com/en/pro-app/latest/help/data/imagery/georeferencing-tools.htm)
# - Start selecting ground control points (GCPs) and try to minimize the Root Mean Squared Error (RMSE) of the georeferenced map
#   - **Select 6-10 GCPs** to apply georeferencing and control the overall errors
# - Rules of selecting GCPs
#   - **Select a fixed object visible in both the image to be georeferenced and the basemap, for example**
#     - Street/block corners
#     - Building corners (be aware of building shape change across years)
#     - Street intersections
#   - Try to spread the GCPs as evenly distributed across the entire map as possible
#     - **DO NOT select your first three GCPs along the same linear structure**
# - Click Save button to apply georeferencing to the historical map
# - You can compare how much difference there is between then and now on our campus and nearby areas in Oxford
# - Once you are done with georeferencing, click **Generate Report** button to calculate the Total RMSE
#   - **Copy and paste your forward and inverse RMSE to [this Google Sheet](https://docs.google.com/spreadsheets/d/1WonAP_gQL_Ra_4R1gZiIZ-vqZ8EkM7Eyyf2160KwCHw/edit?usp=sharing)**
#
# ---

# %% [markdown]
# ### **4. Reflection Questions for the Georeferencing Process**
#
# - **Which locations did you choose for the first three control points, and why did you choose them?**
#
# | GCP      | Location  | Reason of Selection |
# | --------------| ----------- | ----------- |
# | GCP 1     | Intersection of Trenton Oxford Rd and Patterson Avenue  | I choose this location because it is easily identifiable and close to shideler hall |
# | GCP 2     | Intersection of Westgate Drive and US Route 27 | Route 27 was easy to see and it was a point far away from the other GCP |
# | GCP 3     | Where Chestnut Street Begins  | This location made a triangle with the other two locations, which I thought would help make the map's location more accurate  |
#
#
# - **Insert a screenshot of your coordinates table below?**
#
#   - **Original shareable link of screenshot**
#
#   - **Obtain a renderable link**
#
#     - The default link from Google Drive for this picture file cannot be directly used in Notebook to show the picture correctly
#     - Make some changes to the default sharable link:
#       - Deleted **`/view?usp=sharing`** at the end of the link
#       - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#     - Below is a renderable link to insert a picture in Google Colab notebook
#
#   ```markdown
#   https://drive.google.com/uc?export=view&id=1AhZEcVbOntDmG6c830eFDUhrwK3FXjbE
#   ```
#
#   - **Insert a picture with the renderable link**
#
#
#   ![coordinates]( https://drive.google.com/uc?export=view&id=1AhZEcVbOntDmG6c830eFDUhrwK3FXjbE)
#
#
#
# ---

# %% [markdown]
# ### **5. Save the georeferenced map**
#
# - Save your georeferenced map and your ArcGIS Pro project

# %% [markdown]
# ###**6. Save this Google Colab Notebook**
#
# - Save your notebook
# - Make your notebook visible to Anyone with the link
# - Submit a link to this notebook to get another activity done for our Grade Booster
