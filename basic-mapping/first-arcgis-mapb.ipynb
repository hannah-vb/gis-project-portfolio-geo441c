# %% [markdown]
# <a href="https://colab.research.google.com/github/hannah-vb/gis-project-portfolio-geo441c/blob/main/basic-mapping/first-arcgis-mapb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441/541C Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# 🚀 Created by Hannah VanBuren
#
# 01/30/2026

# %% [markdown]
# ### **Get ready to start**

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](PASTE_CANVAS_LINK_HERE)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Upload the PNG file exported from ArcGIS Pro to my Google Drive folder for Week 1 assignment
#    - Change Share privilege to make this file viewable by anyone with a link
#    - Copy the sharable link
#
# 3. **Obtain a sharable link**
#
#    - The default link I get for this PNG file is listed below but it cannot be directly used in Notebook to show the picture correctly
# https://drive.google.com/file/d/PASTE_FILE_ID_HERE/view?usp=sharing
#   - I made some changes to the default sharable link:
#     - Keep the **`1A2B3C4D5E6F7G8H9I0J`** part because this is the unique file ID for the picture
#     - Deleted **`/view?usp=sharing`** at the end of the link
#     - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#    - Here is an example I referred to:
#     - Default sharable link
#
# https://drive.google.com/file/d/1A2B3C4D5E6F7G8H9I0J/view?usp=sharing
#    - The direct link for view from this example would be
#
# https://drive.google.com/uc?export=view&id=1A2B3C4D5E6F7G8H9I0J
#   - The link below is the correct one I need to use in the next section
#
# https://drive.google.com/uc?export=view&id=PASTE_FILE_ID_HERE
#
#
# 4. **Map**
#
#    ![Map](https://drive.google.com/uc?export=view&id=1gjw5hLmPnApzZzKaQn1-pc2QvAy2v6es) <!-- Example Image Placeholder -->

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent 2 hours to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | My map turned out somewhat like the example    | Sizing the map or zooming in the right amount  |
# | Finding where to click got easier as I kept following along with the lesson     | Putting everything in the layout and centering all of the elements of the map    |
# | I feel like a learned a lot about mapping through this first assignment     | Figuring out where to save the map to was difficult   |
#
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - I was able to figure out how to unzip the data by using the extract all feature pretty easily. In addition, finding the data in the catlog of AcrGIS Pro wasn't too difficult either.
#   - Map creation and annotation
#     - I used many different features to create the map in ArcGIS Pro. I used the symbology feature a lot to adjust characteristics of some aspects of the map. For example, changing the thickness and color of roads and streams.
#   - Navigate the software using its GUI
#     - I found that the software was easy to use once I knew where to click to access the feature I wanted. Most of the time I just had a right click on the feature I wanted to change and then look through the options from there.

# %% [markdown]
# ### **Save and share this notebook**
#
# - I made this notebook viewable by anyone with the link
#
# ![Share Notebook](https://drive.google.com/uc?export=view&id=19B_SS87S8C528dAOexxdOLo9B0Sbmrg-)
#
# - Then I copied [this link](https://colab.research.google.com/drive/1SbR1MRUPnmn5e5r2D2mdoGFVdEFyr8NO?usp=sharing) as my submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
